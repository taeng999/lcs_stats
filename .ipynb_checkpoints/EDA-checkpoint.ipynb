# %%
import pandas as pd

# %%
lcs_team = pd.read_csv('./lcs_stat_2018.csv')
lcs_player = pd.read_csv('./lcs_player_2018.csv')

# %%
lcs_team.drop('Unnamed: 0', inplace=True, axis=1)

# %%
lcs_team
# Out:
#                TeamName  GP   W   L   AGT    K    D   K_D  CKPM   GPR   GSPD  \
# 0           100 Thieves  19  13   6  39.1  192  155  1.24  0.47 -0.14  -0.1%
# 1                Cloud9  20  12   8  36.9  223  209  1.07  0.58  0.82   5.1%
# 2         Clutch Gaming  20  11   9  37.7  171  150  1.14  0.43 -0.13   1.1%
# 3  Counter Logic Gaming  18   7  11  38.2  188  212  0.89  0.58 -0.39  -5.4%
# 4              Echo Fox  19  12   7  37.6  243  212  1.15  0.64  0.59   4.1%
# 5              FlyQuest  18   6  12  39.6  156  217  0.72  0.52 -0.59  -6.5%
# 6      Golden Guardians  18   4  14  36.7  156  219  0.71  0.57 -1.00  -6.4%
# 7          OpTic Gaming  18   5  13  39.2  154  198  0.78  0.50 -1.09  -6.8%
# 8           Team Liquid  20  12   8  34.1  190  166  1.14  0.52  0.59   4.5%
# 9          Team SoloMid  20  13   7  39.4  219  154  1.42  0.47  1.12   8.2%
#
#     EGR   MLR
# 0  54.1  14.3
# 1  62.2  -2.2
# 2  42.9  12.1
# 3  50.2 -11.3
# 4  52.2  11.0
# 5  39.4  -6.0
# ...

# %%
lcs_player.drop('Unnamed: 0', inplace=True, axis=1)

# %%
lcs_player
# Out:
#          Player                  Team      Pos  GP   W%   K   D    A  KDA  \
# 0        Adrian              Echo Fox  Support  16  69%   7  38  151  4.2
# 1      Akaadian          OpTic Gaming   Jungle  18  28%  21  33   84  3.2
# 2         Altec              Echo Fox      ADC  19  63%  70  41  110  4.4
# 3          AnDa              FlyQuest   Jungle  16  38%  17  39   99  3.0
# 4      aphromoo           100 Thieves  Support  19  68%   9  40  131  3.5
# 5        Apollo         Clutch Gaming      ADC  20  55%  45  31   84  4.2
# 6         Arrow          OpTic Gaming      ADC  18  28%  44  31   66  3.5
# 7      Biofrost  Counter Logic Gaming  Support  18  39%   9  45  138  3.3
# 8      Bjergsen          Team SoloMid   Middle  20  65%  72  20   98  8.5
# 9      Cody Sun           100 Thieves      ADC  19  68%  79  20   85  8.2
# 10    Contractz      Golden Guardians   Jungle  18  22%  27  56   86  2.0
# 11      Damonte              Echo Fox   Middle   3  33%   8   6   14  3.7
# ...

# %%
lcs_player.groupby('Team').sum
# Out:
#                        GP    K    D    A   KDA  GD10  XPD10  CS-D10  CSPM
# Team
# 100 Thieves            95  192  155  520  24.6    26    175    -3.0  34.8
# Cloud9                100  223  209  580  21.0   541    481    12.6  36.3
# Clutch Gaming         100  171  150  439  22.0  -569   -223    -1.3  35.6
# Counter Logic Gaming   90  188  212  510  16.5   197     56     3.5  34.1
# Echo Fox               95  243  212  632  28.5   376    -68    13.3  46.4
# FlyQuest               90  156  217  450  19.3  -434   -281   -22.7  49.5
# Golden Guardians       90  156  219  416  13.7  -702   -576   -16.6  34.5
# OpTic Gaming           90  154  198  360  15.5  -530   -441   -34.5  41.1
# Team Liquid           100  190  166  499  21.7    19    -32     4.4  37.3
# Team SoloMid          100  219  154  563  29.1   343    180    13.9  36.9
