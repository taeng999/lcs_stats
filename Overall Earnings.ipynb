# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
req = requests.get("https://www.esportsearnings.com/games/164-league-of-legends/top-players")
soup = BeautifulSoup(req.content, 'lxml')

# %%
body = soup.find('body')

# %%
df = pd.DataFrame(columns=['summonerName', 'realName', 'prizeMoney'])
for row in body.find_all('tr'):
    td = row.find_all('td')
    try:
        for a in td[1].find_all('a'): 
            a
        summonerName = (td[1].text)
        realName = td[2].text
        prizeMoney = td[3].text
        df.loc[len(df)] = [summonerName, realName,  prizeMoney]
    except:
        continue

# %%
df
# Out:
#     summonerName            realName     prizeMoney
# 0          Faker     Lee, Sang Hyeok  $1,169,713.35
# 1           Wolf        Lee, Jae Wan    $907,635.50
# 2           Bang        Bae, Jun Sik    $903,134.26
# 3          Bengi      Bae, Seong Ung    $810,683.00
# 4          Blank        Kang, Sun Gu    $554,163.75
# 5       Ambition     Kang, Chan Yong    $535,740.45
# 6           Duke       Lee, Ho Seong    $480,306.06
# 7          Crown         Lee, Min Ho    $465,294.06
# 8          CuVee      Lee, Seong Jin    $462,136.56
# 9        Core JJ         Jo, Yong In    $461,331.59
# 10         Ruler      Park, Jae Hyuk    $458,792.94
# 11          PawN       Heo, Won Seok    $419,762.78
# 12     ClearLove           Ming, Kai    $405,634.72
# 13          Mata      Cho, Se Hyeong    $398,861.78
# 14        Peanut        Han, Wang Ho    $391,933.02
# 15        Impact     Jung, Eon Yeong    $356,597.64
# 16        Looper   Jang, Hyeong Seok    $346,307.48
# 17          Huni     Heo, Seung Hoon    $331,351.04
# 18           Uzi         Jian, Zihao    $323,232.65
# 19          Haru     Kang, Min Seung    $317,303.96
# 20          PraY        Kim, Jong In    $306,408.60
# 21           imp       Gu, Seung Bin    $299,730.28
# 22          bebe       Cheng, Bo Wei    $285,315.32
# 23          Deft       Kim, Hyuk Kyu    $284,938.80
# 24          Mlxg         Liu, Shi Yu    $282,715.27
# 25         DanDy        Choi, In Kyu    $281,150.19
# 26        Piglet     Chae, Gwang Jin    $264,929.15
# 27       GorillA    Kang, Beom Hyeon    $262,652.88
# 28         Koro1          Tong, Yang    $259,298.75
# 29         Meiko            Tian, Ye    $257,766.89
# ..           ...                 ...            ...
# 70       Lustboy       Ham, Jang Sik    $130,020.33
# 71           Ben      Nam, Dong Hyun    $129,687.14
# 72      westdoor        Liu, Shu Wei    $129,318.20
# 73      Hauntzer       Kevin Yarnell    $129,306.40
# 74           MMD        Yau, Li Hung    $128,698.42
# 75       Odoamne        Andrei Pascu    $127,663.12
# 76          Ming       Shi, Sen Ming    $126,961.59
# 77        Meteos     William Hartman    $126,176.67
# 78           kid             Ge, Yan    $126,156.44
# 79         inSec       Choi, In Seok    $124,944.48
# 80      Biofrost        Vincent Wang    $121,406.32
# 81          wuxx         Wang, Cheng    $120,338.48
# 82          dade         Bae, Eo Jin    $118,986.53
# 83       Xmithie        Jake Puchero    $117,712.40
# 84      Alex Ich   Alexey Ichetovkin    $117,224.97
# 85       Cyanide      Lauri Happonen    $115,902.10
# 86   Diamondprox  Daniel Reshetnikov    $114,566.55
# 87        Zzitai         Liu, Zhihao    $114,371.08
# 88       MadLife        Hong, Min Gi    $114,055.46
# 89       Gogoing        Gao, Di Ping    $113,570.08
# 90       WeiXiao      Gao, Xue Cheng    $113,172.97
# 91          Cool         Yu, Jia Jun    $111,855.08
# 92       MrAlbis      Kang, Chia Wei    $110,804.90
# 93      LoveLing             Yin, Le    $110,071.90
# 94         Score        Go, Dong Bin    $109,657.38
# 95         Acorn      Choi, Cheon Ju    $109,619.63
# 96           Shy     Park, Sang Myun    $108,688.04
# 97           san      Guo, Jun Liang    $108,594.22
# 98             U          Ceng, Long    $107,432.88
# 99        jensen      Nicolaj Jensen    $106,215.00
#
# [100 rows x 3 columns]
